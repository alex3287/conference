# %% [markdown]
# # Библиотека Pandas
# ### Рссмотрим объекты Series и DataFrame
#
# * Импортируем библиотеку Pandas и библиотку random
# * Создаем два списка заполненные случайными числами

# %%
import pandas as pd
from random import randint as rnd

A1 = [rnd(-10, 10) for i in range(10)]
B1 = [rnd(-10, 10)/10 for i in range(10,20)]

# %% [markdown]
# ### Создаем и выводим на экран объекты Series
# **Список с вещественными числами делаем индексом Series**

# %%
A = pd.Series(A1, index=list('abcdefghjk'))
B = pd.Series(B1, index=list('abcdefghjk'))
print(A)
print('*'*50)
print(A['c'])
print(A.index)
# Out:
# a   -3
# b    5
# c    9
# d    1
# e   -1
# f   -3
# g    9
# h    6
# j   -6
# k    2
# dtype: int64
# **************************************************
# 9
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'j', 'k'], dtype='object')

# %% [markdown]
# ### Создаем и выводим на экран объект DataFrame

# %%
test = pd.DataFrame({'First': A, 'Second':B})
test
# Out:
#    First  Second
# a     -3    -0.7
# b      5    -0.3
# c      9     1.0
# d      1     1.0
# e     -1     1.0
# f     -3    -0.5
# g      9     0.1
# h      6     0.8
# j     -6    -0.9
# k      2     0.4

# %% [markdown]
# ### Визуалицация данных

# %%
test.plot()

# %% [markdown]
# # Компьютерная модель движения тела на языке Python
#
# ### На основе формальной модели, описывающей движение тела, брошенного под углом к горизонту, создадим компьютерную модель с использованием системы программирования Jupyter notebook
#
# ## Проект "Бросание мячика в стенку" на языке Python

# %%
import math

# %% [markdown]
# ### Объявим необходимые переменные

# %%
V0 = 18 # начальная скорость
A = 45  # угол бросания мяча
S = 15  # расстояние до стены
H = 2   # высота стены
G = 9.81 # ускоренее свободного падения

# %%
# Попадание в стену
L = S * math.tan(A*math.pi / 180) - G * S**2 / (2 * (V0 * math.cos(A * math.pi/180)))

# %%
if L < 0:
    print('Недолет')
elif L > H:
    print('Перелет')
else:
    print('Попадание')
# Out:
# Недолет
# 23

# %%
T = [i/10 for i in range(20)]
x = [(5 + round(10*(V0*math.cos(A*math.pi/180)*i))) for i in range(20)]
y = [(180 - round(10*(V0*math.sin(A*math.pi/180)*T-G*T*T/2))) for T in range(20)]
# print(step)
print(x)
print(y)
# for i in y:
#     if i < 0:
#         break
# t = y.index(i)
# print(t, y[t])
# Out:
# [5, 132, 260, 387, 514, 641, 769, 896, 1023, 1151, 1278, 1405, 1532, 1660, 1787, 1914, 2041, 2169, 2296, 2423]
# [180, 102, 122, 240, 456, 770, 1182, 1692, 2301, 3008, 3812, 4715, 5716, 6815, 8012, 9307, 10700, 12192, 13781, 15469]

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.plot(x[:t],y[:t])
plt.plot([S,S],[0,H])
# plt.plot(y)
plt.title('Test')
plt.ylabel('hieght m')
plt.xlabel('distans (m)')
# plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Взять для следующего проекта

# %%
import numpy as np

x = np.linspace(0, 2, 100)
# Note that even in the OO-style, we use `.pyplot.figure` to create the figure. 
fig, ax = plt.subplots() # Create a figure and an axes.
ax.plot(x, x, label='linear') # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic') # Plot more data on the axes... 
ax.plot(x, x**3, label='cubic') # ... and some more.
ax.set_xlabel('x label') # Add an x-label to the axes. 
ax.set_ylabel('y label') # Add a y-label to the axes. 
ax.set_title("Simple Plot") # Add a title to the axes. 
ax.legend() # Add a legend.
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Работаем с DataFrame и Series

# %%
import pandas as pd
from random import randint as rnd
A1 = [rnd(-10, 10) for i in range(10)]
B1 = [rnd(-10, 10)/10 for i in range(10,20)]

A = pd.Series(A1)
B = pd.Series(B1)
test = pd.DataFrame({'First': A, 'Second':B})
test
# Out:
#    First  Second
# 0     -8     0.8
# 1      7     0.5
# 2      6     1.0
# 3      9    -0.3
# 4     -6     0.0
# 5      3     0.1
# 6      4    -0.6
# 7      6     0.3
# 8      0     0.5
# 9     -2    -0.9

# %% [markdown]
# ## Визуализация данных

# %%
test.Second.plot()
